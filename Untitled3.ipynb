# %% [markdown]
# <a href="https://colab.research.google.com/github/laurahallaman1/final_project/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas as pd

# # read data
# reviews_df = pd.read_csv("https:/raw.githubusercontent.com/laurahallaman1/final_project/codyfiles/Combined_Amazon_Consumer_Reviews")
# # # append the positive and negative text reviews
# reviews_df["is_bad_review"] = reviews_df["rating"].apply(lambda x: 1 if x < 3 else 0)
# # select only relevant columns
# reviews_df = reviews_df[["review", "is_bad_review"]]
# reviews_df.head()


import pandas as pd
import io
import requests
# url="https:/raw.githubusercontent.com/laurahallaman1/final_project/codyfiles/Combined_Amazon_Consumer_Reviews"
# s=requests.get(url).content
# c_df=pd.read_csv(io.StringIO(s.decode('utf-8')))
reviews_df = pd.read_csv("C:\Users\Cody\Documents\GitHub\final_project\Combined_Amazon_Consumer_Reviews.csv")
reviews_df["is_bad_review"] = c_df["rating"].apply(lambda x: 1 if x < 3 else 0)
reviews_df = reviews_df[["new_review", "is_bad_review"]]
reviews_df.head()
# Out:
#   File "<ipython-input-32-debd0860b29d>", line 9
#     reviews_df = pd.read_csv("C:\Users\Cody\Documents\GitHub\final_project\Combined_Amazon_Consumer_Reviews.csv")
#                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pwd
# Out:
# '/content'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 20000,
        max_font_size = 40, 
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()
    
# print wordcloud
show_wordcloud(c_df["new_review"])
