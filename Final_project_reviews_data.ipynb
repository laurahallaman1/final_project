# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine

# %%
amzn_reviews = pd.read_csv("https://raw.githubusercontent.com/laurahallaman1/final_project/codyfiles/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv")
amzn_reviews
# Out:
#                          id             dateAdded           dateUpdated  \
# 0      AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1      AVpjEN4jLJeJML43rpUe  2016-06-08T03:50:06Z  2019-02-25T02:05:58Z
# 2      AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2019-02-25T02:20:29Z
# 3      AVpgdkC8ilAPnD_xsvyi  2016-04-10T22:00:34Z  2019-03-03T02:47:22Z
# 4      AVzYlGkFvKc47QAVeZRI  2017-06-24T05:30:23Z  2019-02-25T02:23:15Z
# ...                     ...                   ...                   ...
# 28333  AVqVGWQDv8e3D1O-ldFr  2017-03-03T16:55:53Z  2019-03-09T07:13:43Z
# 28334  AVph0EeEilAPnD_x9myq  2017-01-11T06:58:33Z  2019-02-25T02:05:06Z
# 28335  AVpfw2hvilAPnD_xh0rH  2017-01-11T06:58:33Z  2019-03-09T07:13:43Z
# 28336  AVpe7xlELJeJML43ypLz  2015-12-03T01:23:41Z  2019-04-24T02:17:42Z
# 28337  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                     name  \
# ...

# %%
amzn_reviews_clean = amzn_reviews.drop(["dateUpdated", "dateAdded", "asins", "reviews.date",\
                                                 "reviews.dateSeen", "reviews.didPurchase", "reviews.doRecommend",\
                                                 "reviews.numHelpful"], axis=1)
amzn_reviews_clean
# Out:
#                          id  \
# 0      AVpgNzjwLJeJML43Kpxn
# 1      AVpjEN4jLJeJML43rpUe
# 2      AVqkIdZiv8e3D1O-leaJ
# 3      AVpgdkC8ilAPnD_xsvyi
# 4      AVzYlGkFvKc47QAVeZRI
# ...                     ...
# 28333  AVqVGWQDv8e3D1O-ldFr
# 28334  AVph0EeEilAPnD_x9myq
# 28335  AVpfw2hvilAPnD_xh0rH
# 28336  AVpe7xlELJeJML43ypLz
# 28337  AVpgNzjwLJeJML43Kpxn
#
#                                                     name  \
# 0      AmazonBasics AAA Performance Alkaline Batterie...
# 1      Fire Tablet with Alexa, 7 Display, 16 GB, Blue...
# 2      Fire Tablet with Alexa, 7 Display, 16 GB, Mage...
# 3      Fire Tablet, 7 Display, Wi-Fi, 16 GB - Include...
# 4      All-New Fire HD 8 Tablet with Alexa, 8 HD Disp...
# ...                                                  ...
# 28333  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 28334  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# 28335  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# ...
